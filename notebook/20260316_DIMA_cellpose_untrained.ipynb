# %%
# On nettoie tout pour éviter les mélanges Numpy 1 et 2
# !pip uninstall -y cellpose numpy opencv-python opencv-contrib-python
# On installe le stack cohérent pour Cellpose 3
# !pip install "numpy<2.0" "opencv-python==4.8.0.74" cellpose==3.0.10 -q
# Out:
# Found existing installation: cellpose 3.0.10
# Uninstalling cellpose-3.0.10:
#   Successfully uninstalled cellpose-3.0.10
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Found existing installation: opencv-python 4.13.0.92
# Uninstalling opencv-python-4.13.0.92:
#   Successfully uninstalled opencv-python-4.13.0.92
# Found existing installation: opencv-contrib-python 4.13.0.92
# Uninstalling opencv-contrib-python-4.13.0.92:
#   Successfully uninstalled opencv-contrib-python-4.13.0.92
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 14.0 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0
# Mon Mar 16 17:57:51 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# ...

# %%
import os, shutil
import numpy as np
import matplotlib.pyplot as plt
from cellpose import core, utils, io, models, metrics
from glob import glob

# %%
use_GPU = core.use_gpu()
yn = ['NO', 'YES']
print(f'>>> GPU activated? {yn[use_GPU]}')
# Out:
# >>> GPU activated? YES

# %%
# 1. Setup des logs (pour voir l'avancement)
io.logger_setup()

# 2. Charger le modèle standard (SANS denoise)
# cyto3 est le dernier modèle généraliste ultra-performant
model = models.CellposeModel(gpu=True, model_type="cyto3")


# dossier = Path('data/1-Images/01-Data/')
# fichiers = list(dossier.glob('*_AF.png'))

# for f in fichiers[:3]: 
#     img = cv2.imread(str(f), cv2.IMREAD_UNCHANGED)
#     masks, flows, styles, diams = model.eval(img, diameter=None, channels=[0,0])

#     fig = plt.figure(figsize=(12,5))
#     plot.show_segmentation(fig, img, masks, flows[0], channels=[0,0])
#     plt.title(f"Segmentation de {f.name}")
#     plt.show()

path = '../data/1-Images/01-Data/001_study1_image001_AF.png'
img = cv2.imread(path, cv2.IMREAD_UNCHANGED)

masks, flows, styles = model.eval(img, 
                                  diameter=None, 
                                  channels=[0,0],
                                  resample=True)
# Out:
# creating new log file
# 2026-03-16 18:13:53,826 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2026-03-16 18:13:53,828 [INFO]
# cellpose version: 	4.0.9
# platform:       	linux
# python version: 	3.12.12
# torch version:  	2.10.0+cu128
# 2026-03-16 18:13:53,829 [WARNING] model_type argument is not used in v4.0.1+. Ignoring this argument...
# 2026-03-16 18:13:53,830 [INFO] ** TORCH CUDA version installed and working. **
# 2026-03-16 18:13:53,831 [INFO] >>>> using GPU (CUDA)
# 2026-03-16 18:13:56,266 [INFO] Downloading: "https://huggingface.co/mouseland/cellpose-sam/resolve/main/cpsam" to /root/.cellpose/models/cpsam
# 100%|██████████| 1.15G/1.15G [00:16<00:00, 74.9MB/s]
# 2026-03-16 18:14:14,065 [WARNING] channels deprecated in v4.0.1+. If data contain more than 3 channels, only the first 3 channels will be used
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...
